# %% [markdown]
# <a href="https://colab.research.google.com/github/romain68jablonski-web/PUC-EEIGM/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# entraînement

# %%
# !git clone https://github.com/romain68jablonski-web/PUC-EEIGM/
# Out:
# Cloning into 'PUC-EEIGM'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 16 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (16/16), 14.25 MiB | 8.06 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
import skimage as sk
from skimage import io
I= sk.io.imread ('/content/PUC-EEIGM/mammograph.tif')

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,6))
sk.io.imshow(I) # visualize image using imshow function
sk.io.show()
# Out:
# /tmp/ipython-input-1534323884.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   sk.io.imshow(I) # visualize image using imshow function
# /tmp/ipython-input-1534323884.py:4: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   sk.io.show()

# %%
from google.colab import files
import io
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b2ec3307-e807-4234-9170-5789732518e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2ec3307-e807-4234-9170-5789732518e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import skimage as sk
from skimage import io
I= sk.io.imread ()
